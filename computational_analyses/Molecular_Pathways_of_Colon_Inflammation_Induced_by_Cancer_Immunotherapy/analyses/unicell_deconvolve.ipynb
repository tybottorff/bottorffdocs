# %% [markdown]
# # Read in libraries

# %%
import ucdeconvolve as ucd
import scanpy as sc

# %% [markdown]
# # Read in h5ad object (from Seurat object of T cells)

# %%
h5adFile = "../saved_data/t_cells.h5ad"
h5ad = sc.read_h5ad(h5adFile)

# %% [markdown]
# # Run cell typing

# %%
ucd.tl.base(h5ad)
# Out:
# 2024-02-21 13:44:13,086|[UCD]|INFO: Starting UCDeconvolveBASE Run. | Timer Started.
# Preprocessing Dataset |   0% (0 of 201) || Elapsed Time: 0:00:00 ETA:  --:--:--
# Preprocessing Dataset |   0% (1 of 201) || Elapsed Time: 0:00:00 ETA:   0:00:59
# Preprocessing Dataset |   0% (2 of 201) || Elapsed Time: 0:00:00 ETA:   0:01:00
# Preprocessing Dataset |   1% (3 of 201) || Elapsed Time: 0:00:00 ETA:   0:01:00
# Preprocessing Dataset |   1% (4 of 201) || Elapsed Time: 0:00:01 ETA:   0:01:00
# Preprocessing Dataset |   2% (5 of 201) || Elapsed Time: 0:00:01 ETA:   0:00:59
# Preprocessing Dataset |   2% (6 of 201) || Elapsed Time: 0:00:01 ETA:   0:00:59
# Preprocessing Dataset |   3% (7 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:59
# Preprocessing Dataset |   3% (8 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:58
# Preprocessing Dataset |   4% (9 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:58
# Preprocessing Dataset |   4% (10 of 201) || Elapsed Time: 0:00:03 ETA:   0:00:57
# ...
