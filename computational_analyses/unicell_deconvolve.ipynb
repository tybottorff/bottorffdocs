# %% [markdown]
# # Read in libraries

# %%
import ucdeconvolve as ucd
import scanpy as sc

# %% [markdown]
# # Register, activate, authenticate UCD

# %%
ucd.api.register()
ucd.api.activate(code)
ucd.api.authenticate(token)
# Out:
# Please check inbox at dmcharytonowicz@gmail.com and copy/paste activation code into prompt below.
# 2024-02-26 09:30:56,575|[UCD]|ERROR:
# <!doctype html>
# <html lang="en">
# <head>
#   <title>Server Error (500)</title>
# </head>
# <body>
#   <h1>Server Error (500)</h1><p></p>
# </body>
# </html>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 ucd.api.register()
#       2 ucd.api.activate(code)
#       3 ucd.api.authenticate(token)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ucdeconvolve/_api/_api.py:121, in register(username, password, firstname, lastname, email, institution, dynamic)
#     118 activation_code = getpass("Activation Code: ")
#     120 # Process activation
# --> 121 return activate(activation_code)
#
# ...

# %% [markdown]
# # Read in h5ad object (from Seurat object of T cells)

# %%
h5adFile = "luoma_cell_2020/saved_data/t_cells_sct.h5ad"
h5ad = sc.read_h5ad(h5adFile)

# %% [markdown]
# # Run cell typing

# %%
ucd.tl.base(h5ad)
# Out:
# 2024-02-26 09:23:59,715|[UCD]|INFO: Starting UCDeconvolveBASE Run. | Timer Started.
# Preprocessing Dataset |   0% (0 of 201) || Elapsed Time: 0:00:00 ETA:  --:--:--
# Preprocessing Dataset |   0% (1 of 201) || Elapsed Time: 0:00:00 ETA:   0:01:07
# Preprocessing Dataset |   0% (2 of 201) || Elapsed Time: 0:00:00 ETA:   0:01:03
# Preprocessing Dataset |   1% (3 of 201) || Elapsed Time: 0:00:00 ETA:   0:01:02
# Preprocessing Dataset |   1% (4 of 201) || Elapsed Time: 0:00:01 ETA:   0:01:01
# Preprocessing Dataset |   2% (5 of 201) || Elapsed Time: 0:00:01 ETA:   0:01:01
# Preprocessing Dataset |   2% (6 of 201) || Elapsed Time: 0:00:01 ETA:   0:01:00
# Preprocessing Dataset |   3% (7 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:59
# Preprocessing Dataset |   3% (8 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:58
# Preprocessing Dataset |   4% (9 of 201) || Elapsed Time: 0:00:02 ETA:   0:00:58
# Preprocessing Dataset |   4% (10 of 201) || Elapsed Time: 0:00:03 ETA:   0:00:57
# ...
